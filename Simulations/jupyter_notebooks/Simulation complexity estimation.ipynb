# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
twoN = np.arange(10, 28)

# %%
Stime = [2.598, 2.788, 3.024, 3.135, 3.457, 3.426, 3.626, 3.812, 4.163, 4.402, 4.802, 5.482, 7.165, 9.954, 18.437, 33.394, 61.891, 628.466]

# %%
plt.figure(figsize=(16,8))
plt.plot(twoN, np.log10(Stime))
plt.xlabel('LClength_in')
plt.ylabel('Time (s)')
plt.show()
# plt.semilogy(twoN, Stime)
# plt.xlabel('LClength_in')
# plt.ylabel('Time (s)')
# plt.show()
